# %% [markdown]
# PPT LINK : https://docs.google.com/presentation/d/1W8xrLEBxcc8WanDVHHm8ZgfaIxBdGCBa/edit?usp=sharing&ouid=106702906048169590831&rtpof=true&sd=true

# %%
path="/content/drive/MyDrive/BANK MARKETING/bank_marketing .csv"

# %%
import pandas as pd
df=pd.read_csv(path)

# %%
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df.drop_duplicates()
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# **Histogram of age distribution:**

# %%
import matplotlib.pyplot as plt
plt.hist(df['age'], bins=20)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Bar plot of outcome of the previous marketing campaign**

# %%
import seaborn as sns
sns.countplot(x='poutcome', data=df)
plt.show()

# %% [markdown]
# **Bar plot of whether the client has subscribed a term deposit**

# %%
sns.countplot(x='y', data=df)
plt.show()

# %% [markdown]
# **Histogram of last contact duration**

# %%
plt.hist(df['duration'], bins=20)
plt.xlabel('Duration')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Bar plot of number of contacts performed during this campaign and for this client**

# %%
sns.countplot(x='campaign', data=df)
plt.show()

# %% [markdown]
# **Heatmap of the correlation matrix for the numeric attributes in the bank marketing dataset**

# %%
numeric_cols = ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']
corr_matrix = df[numeric_cols].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# **Bar plot of last contact month of year**

# %%
sns.countplot(x='month', data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Histogram of last contact day of the month**

# %%
plt.hist(df['day'], bins=31)
plt.xlabel('Day')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Bar plot of contact communication type**

# %%
sns.countplot(x='contact', data=df)
plt.show()

# %% [markdown]
# **Pie chart of marital status**

# %%
plt.pie(df['marital'].value_counts(), labels=df['marital'].unique())
plt.show()

# %% [markdown]
# **Box plot of balance**

# %%
sns.boxplot(x='balance', data=df)
plt.show()

# %% [markdown]
# **Box plot of balance with hue as whether the client has subscribed a term deposit**

# %%
sns.boxplot(x='y', y='balance', data=df)
plt.show()

# %%
job_mapping = {"unemployed": 0,"services": 1,"management": 1,"blue-collar": 1,
"self-employed": 1,"technician": 1,"entrepreneur": 1,"admin.": 1,"student": 1,
"housemaid": 1,"retired": 0,"unknown": 0}
df['job'] = df['job'].map(job_mapping)

# %%
marital_mapping = {"married": 0,"divorced": 1,"single": 1}
df['marital'] = df['marital'].map(marital_mapping)

# %%
education_mapping = {"primary": 1,"secondary": 2,"tertiary": 3,"unknown": 0}
df['education'] = df['education'].map(education_mapping)

# %%
df['month'].replace({'jan': 'Quater_1', 'feb': 'Quater_1', 'mar': 'Quater_1', 'apr': 'Quater_2', 'may': 'Quater_2', 'jun': 'Quater_2', 'jul': 'Quater_3', 'aug': 'Quater_3', 'sep': 'Quater_3', 'oct': 'Quater_4', 'nov': 'Quater_4', 'dec': 'Quater_4'}, inplace=True)
df = pd.get_dummies(df, columns=['month'],drop_first=True)

# %%
poutcome_mapping = {"unknown": 0,"other": 0,"failure": 0,"success": 1}
df['poutcome'] = df['poutcome'].map(poutcome_mapping)

# %%
contact_mapping = {"telephone": 0,"cellular": 0,"unknown": 1}
df['contact'] = df['contact'].map(contact_mapping)

# %%
binary_cols = ['default', 'housing', 'loan', 'y']
df[binary_cols] = df[binary_cols].replace({'yes': 1, 'no': 0})

# %%
from sklearn.model_selection import train_test_split

# %%
import numpy as np
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
logreg_model = LogisticRegression(max_iter=1000)
logreg_model.fit(X_train_scaled, y_train)
y_pred = logreg_model.predict(X_test_scaled)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
# [[1365   51]
#  [  49  118]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      1416
#            1       0.70      0.71      0.70       167
#
#     accuracy                           0.94      1583
#    macro avg       0.83      0.84      0.83      1583
# weighted avg       0.94      0.94      0.94      1583

# %%
from sklearn.svm import SVC
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
svm_model = SVC()
svm_model.fit(X_train, y_train)
y_pred = svm_model.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
# [[804   0]
#  [101   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       804
#            1       0.00      0.00      0.00       101
#
#     accuracy                           0.89       905
#    macro avg       0.44      0.50      0.47       905
# weighted avg       0.79      0.89      0.84       905
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(X_train, y_train)
y_pred = knn_model.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
# [[774  30]
#  [ 89  12]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       804
#            1       0.29      0.12      0.17       101
#
#     accuracy                           0.87       905
#    macro avg       0.59      0.54      0.55       905
# weighted avg       0.83      0.87      0.84       905

# %%
from sklearn.tree import DecisionTreeClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42)
dt_model = DecisionTreeClassifier(max_depth=5)
dt_model.fit(X_train, y_train)
y_pred = dt_model.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
# [[1399   17]
#  [  29  138]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1416
#            1       0.89      0.83      0.86       167
#
#     accuracy                           0.97      1583
#    macro avg       0.94      0.91      0.92      1583
# weighted avg       0.97      0.97      0.97      1583

# %%
from sklearn.ensemble import RandomForestClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
rf_model = RandomForestClassifier(n_estimators=100,max_depth=7, random_state=42)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
# [[801   3]
#  [ 24  77]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       804
#            1       0.96      0.76      0.85       101
#
#     accuracy                           0.97       905
#    macro avg       0.97      0.88      0.92       905
# weighted avg       0.97      0.97      0.97       905

# %%
from sklearn.ensemble import AdaBoostClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42)
adaboost_model = AdaBoostClassifier()
adaboost_model.fit(X_train, y_train)
y_pred = adaboost_model.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
# [[1405   11]
#  [  26  141]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1416
#            1       0.93      0.84      0.88       167
#
#     accuracy                           0.98      1583
#    macro avg       0.95      0.92      0.94      1583
# weighted avg       0.98      0.98      0.98      1583

# %%
from sklearn.ensemble import GradientBoostingClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
gb_model = GradientBoostingClassifier(max_depth=7)
gb_model.fit(X_train, y_train)
y_pred = gb_model.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
# [[796   8]
#  [ 17  84]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       804
#            1       0.91      0.83      0.87       101
#
#     accuracy                           0.97       905
#    macro avg       0.95      0.91      0.93       905
# weighted avg       0.97      0.97      0.97       905

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42)
xgb_model = XGBClassifier(max_depth=7)
xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
# [[1403   13]
#  [  27  140]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1416
#            1       0.92      0.84      0.88       167
#
#     accuracy                           0.97      1583
#    macro avg       0.95      0.91      0.93      1583
# weighted avg       0.97      0.97      0.97      1583
